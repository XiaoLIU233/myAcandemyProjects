# %%
# Importing modules
import pandas as pd
import matplotlib.pyplot as plt

# Reading in datasets/book1.csv
book1 = pd.read_csv("asoiaf-book1-edges.csv")
book1.head()
# Out:
#                             Source              Target        Type  weight  \
# 0                   Addam-Marbrand     Jaime-Lannister  Undirected       3
# 1                   Addam-Marbrand     Tywin-Lannister  Undirected       6
# 2                Aegon-I-Targaryen  Daenerys-Targaryen  Undirected       5
# 3                Aegon-I-Targaryen        Eddard-Stark  Undirected       4
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne  Undirected       4
#
#    book  new_weight
# 0     1         289
# 1     1         286
# 2     1         287
# 3     1         288
# 4     1         288

# %%
# Importing modules
import networkx as nx

# Creating an empty graph object
G_book1 = nx.Graph()

# %%
# Iterating through the DataFrame to add edges
for _,edge in book1.iterrows():
    G_book1.add_edge(edge['Source'], edge['Target'], weight=edge['new_weight'])

# Creating a list of networks for all the books
books = [G_book1]
book_fnames = ['asoiaf-book2-edges.csv', 'asoiaf-book3-edges.csv', 'asoiaf-book4-edges.csv', 'asoiaf-book5-edges.csv','asoiaf-all-edges.csv']
for book_fname in book_fnames:
    book = pd.read_csv(book_fname)
    G_book = nx.Graph()
    for _,edge in book.iterrows():
        G_book.add_edge(edge['Source'], edge['Target'], weight=edge['new_weight'])
    books.append(G_book)

# %%
# Calculating the degree centrality of book 1
deg_cen_book1 = nx.degree_centrality(books[0])

# Calculating the degree centrality of book 2
deg_cen_book2 = nx.degree_centrality(books[1])

# Calculating the degree centrality of book 3
deg_cen_book3 = nx.degree_centrality(books[2])

# Calculating the degree centrality of book 4
deg_cen_book4 = nx.degree_centrality(books[3])

# Calculating the degree centrality of book 5
deg_cen_book5 = nx.degree_centrality(books[4])

# Calculating the degree centrality of ALLBook
deg_cen_book_all = nx.degree_centrality(books[5])


# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book1 = sorted(deg_cen_book1.items(), key=lambda x:x[1], reverse=True)[0:10]

# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book2 = sorted(deg_cen_book2.items(), key=lambda x:x[1], reverse=True)[0:10]

# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book3 = sorted(deg_cen_book3.items(), key=lambda x:x[1], reverse=True)[0:10]

# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book4 = sorted(deg_cen_book4.items(), key=lambda x:x[1], reverse=True)[0:10]

# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book5 = sorted(deg_cen_book5.items(), key=lambda x:x[1], reverse=True)[0:10]

# Sorting the dictionaries according to their degree centrality and storing the top 10
sorted_deg_cen_book_all = sorted(deg_cen_book_all.items(), key=lambda x:x[1], reverse=True)[0:10]

# Printing out the top 10 of book1 and book5
print('Degree Centrality:'+'\n'+'Top10 of book1: ','\n', sorted_deg_cen_book1, '\n')
print('Top10 of book2: ','\n', sorted_deg_cen_book2, '\n')
print('Top10 of book3: ','\n', sorted_deg_cen_book3, '\n')
print('Top10 of book4: ','\n',sorted_deg_cen_book4, '\n')
print('Top10 of book5: ','\n',sorted_deg_cen_book5, '\n')
print('Top10 of book_all: ','\n', sorted_deg_cen_book_all)
# Out:
# Degree Centrality:
# Top10 of book1:
#  [('Eddard-Stark', 0.3548387096774194), ('Robert-Baratheon', 0.2688172043010753), ('Tyrion-Lannister', 0.24731182795698928), ('Catelyn-Stark', 0.23118279569892475), ('Jon-Snow', 0.19892473118279572), ('Robb-Stark', 0.18817204301075272), ('Sansa-Stark', 0.18817204301075272), ('Bran-Stark', 0.17204301075268819), ('Cersei-Lannister', 0.16129032258064518), ('Joffrey-Baratheon', 0.16129032258064518)]
#
# Top10 of book2:
#  [('Tyrion-Lannister', 0.2054263565891473), ('Joffrey-Baratheon', 0.1821705426356589), ('Cersei-Lannister', 0.16666666666666666), ('Arya-Stark', 0.15503875968992248), ('Stannis-Baratheon', 0.1434108527131783), ('Robb-Stark', 0.13565891472868216), ('Catelyn-Stark', 0.12790697674418605), ('Theon-Greyjoy', 0.12403100775193798), ('Renly-Baratheon', 0.12015503875968991), ('Bran-Stark', 0.11627906976744186)]
#
# Top10 of book3:
# ...

# %% [raw]
# This is the chart for degree centrality for book 1-5

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
top_charcter_book1 = []
deg_cen_book1 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book1[num][0]
    deg_cen = sorted_deg_cen_book1[num][1]
    top_charcter_book1.append(name)
    deg_cen_book1.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book1 , deg_cen_book1, width=0.5)
plt.savefig('DC_top_charcter_book1.png')
plt.show()

# %% [markdown]
#                                      The degree centrality in Book1

# %%
top_charcter_book2 = []
deg_cen_book2 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book2[num][0]
    deg_cen = sorted_deg_cen_book2[num][1]
    top_charcter_book2.append(name)
    deg_cen_book2.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book2 , deg_cen_book2, width=0.5)
plt.savefig('DC_top_charcter_book2.png')
plt.show()

# %% [markdown]
#                                         The degree centrality in Book2

# %%
top_charcter_book3 = []
deg_cen_book3 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book3[num][0]
    deg_cen = sorted_deg_cen_book3[num][1]
    top_charcter_book3.append(name)
    deg_cen_book3.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book3 , deg_cen_book3, width=0.5)
plt.savefig('DC_top_charcter_book3.png')
plt.show()

# %% [markdown]
#                                         The degree centrality in Book3

# %%
top_charcter_book4 = []
deg_cen_book4 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book4[num][0]
    deg_cen = sorted_deg_cen_book4[num][1]
    top_charcter_book4.append(name)
    deg_cen_book4.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book4 , deg_cen_book4, width=0.5)
plt.savefig('DC_top_charcter_book4.png')
plt.show()

# %% [markdown]
#                                                 The degree centrality in Book4

# %%
top_charcter_book5 = []
deg_cen_book5 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book5[num][0]
    deg_cen = sorted_deg_cen_book5[num][1]
    top_charcter_book5.append(name)
    deg_cen_book5.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book5 , deg_cen_book5, width=0.5)
plt.savefig('DC_top_charcter_book5.png')
plt.show()

# %%
top_charcter_book_all = []
deg_cen_book_all = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_deg_cen_book_all[num][0]
    deg_cen = sorted_deg_cen_book_all[num][1]
    top_charcter_book_all.append(name)
    deg_cen_book_all.append(deg_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(top_charcter_book_all , deg_cen_book_all, width=0.5)
plt.savefig('DC_top_charcter_book_all.png')
plt.show()

# %% [markdown]
#                                             The degree centrality in Book5

# %%
# %matplotlib inline

# Creating a list of degree centrality of all the books
evol = [nx.degree_centrality(book) for book in books]
 
# Creating a DataFrame from the list of degree centralities in all the books
# Because it's possible that a character is not in every book, so use .fillna(0) to prevent `NaN` entries.
idx = ['book1', 'book2', 'book3', 'book4', 'book5','book_all']
degree_evol_df = pd.DataFrame.from_records(evol, index=idx).fillna(0)

# Plotting the degree centrality evolution of Eddard-Stark, Tyrion-Lannister and Jon-Snow
degree_evol_df.plot(y=['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow','Daenerys-Targaryen'],linewidth=5.0)

# %% [markdown]
#                                 The snow and fire... & Poor Eddard-Stark

# %% [markdown]
# Between centrality Calculate

# %%
#Betweenness centrality of book1
bet_cen_book1 = nx.betweenness_centrality(books[0], weight='new_weight')
bet_cen_book2 = nx.betweenness_centrality(books[1], weight='new_weight')
bet_cen_book3 = nx.betweenness_centrality(books[2], weight='new_weight')
bet_cen_book4 = nx.betweenness_centrality(books[3], weight='new_weight')
bet_cen_book5 = nx.betweenness_centrality(books[4], weight='new_weight')
bet_cen_book_all = nx.betweenness_centrality(books[5], weight='new_weight')

#Sort list
sorted_bet_cen_book1 = sorted(bet_cen_book1.items(), key=lambda x:x[1], reverse=True)[0:10]
sorted_bet_cen_book2 = sorted(bet_cen_book2.items(), key=lambda x:x[1], reverse=True)[0:10]
sorted_bet_cen_book3 = sorted(bet_cen_book3.items(), key=lambda x:x[1], reverse=True)[0:10]
sorted_bet_cen_book4 = sorted(bet_cen_book4.items(), key=lambda x:x[1], reverse=True)[0:10]
sorted_bet_cen_book5 = sorted(bet_cen_book5.items(), key=lambda x:x[1], reverse=True)[0:10]
sorted_bet_cen_book_all = sorted(bet_cen_book_all.items(), key=lambda x:x[1], reverse=True)[0:10]

#Print
print('top10 of book1: ','\n', sorted_bet_cen_book1, '\n')
print('top10 of book2: ','\n', sorted_bet_cen_book2, '\n')
print('top10 of book3: ','\n', sorted_bet_cen_book3, '\n')
print('top10 of book4: ','\n', sorted_bet_cen_book4, '\n')
print('top10 of book5: ','\n', sorted_bet_cen_book5, '\n')
print('top10 of ALL Book: ','\n', sorted_bet_cen_book_all, '\n')
# Out:
# top10 of book1:
#  [('Eddard-Stark', 0.2696038913836117), ('Robert-Baratheon', 0.21403028397371796), ('Tyrion-Lannister', 0.1902124972697492), ('Jon-Snow', 0.17158135899829566), ('Catelyn-Stark', 0.1513952715347627), ('Daenerys-Targaryen', 0.08627015537511595), ('Robb-Stark', 0.07298399629664767), ('Drogo', 0.06481224290874964), ('Bran-Stark', 0.05579958811784442), ('Sansa-Stark', 0.03714483664326785)]
#
# top10 of book2:
#  [('Arya-Stark', 0.1881116846731781), ('Jon-Snow', 0.17443976935054054), ('Robb-Stark', 0.1649406213117506), ('Tyrion-Lannister', 0.15532375650368552), ('Robert-Baratheon', 0.15374366220396257), ('Theon-Greyjoy', 0.14439534223860254), ('Stannis-Baratheon', 0.11951360907930143), ('Bran-Stark', 0.11323494837768544), ('Catelyn-Stark', 0.11104383596371503), ('Joffrey-Baratheon', 0.09078190285323477)]
#
# top10 of book3:
# ...

# %%
bc_top_charcter_book1 = []
bet_cen_book1 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book1[num][0]
    bet_cen = sorted_bet_cen_book1[num][1]
    bc_top_charcter_book1.append(name)
    bet_cen_book1.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book1 , bet_cen_book1, width=0.5)
plt.savefig('BC_top_charcter_book1.png')
plt.show()

# %%
bc_top_charcter_book2 = []
bet_cen_book2 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book2[num][0]
    bet_cen = sorted_bet_cen_book2[num][1]
    bc_top_charcter_book2.append(name)
    bet_cen_book2.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book2 , bet_cen_book2, width=0.5)
plt.savefig('BC_top_charcter_book2.png')
plt.show()

# %%
bc_top_charcter_book3 = []
bet_cen_book3 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book3[num][0]
    bet_cen = sorted_bet_cen_book3[num][1]
    bc_top_charcter_book3.append(name)
    bet_cen_book3.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book3 , bet_cen_book3, width=0.5)
plt.savefig('BC_top_charcter_book3.png')
plt.show()

# %%
bc_top_charcter_book4 = []
bet_cen_book4 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book4[num][0]
    bet_cen = sorted_bet_cen_book4[num][1]
    bc_top_charcter_book4.append(name)
    bet_cen_book4.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book4 , bet_cen_book4, width=0.5)
plt.savefig('BC_top_charcter_book4.png')
plt.show()

# %%
bc_top_charcter_book5 = []
bet_cen_book5 = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book5[num][0]
    bet_cen = sorted_bet_cen_book5[num][1]
    bc_top_charcter_book5.append(name)
    bet_cen_book5.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book5 , bet_cen_book5, width=0.5)
plt.savefig('BC_top_charcter_book5.png')
plt.show()

# %%
bc_top_charcter_book_all = []
bet_cen_book_all = []
for num in range(0,10):  # 迭代 10 到 20 之间的数字
    name = sorted_bet_cen_book_all[num][0]
    bet_cen = sorted_bet_cen_book_all[num][1]
    bc_top_charcter_book_all.append(name)
    bet_cen_book_all.append(bet_cen)
plt.figure(figsize=(19, 12)) 
plt.bar(bc_top_charcter_book_all , bet_cen_book_all, width=0.5)
plt.savefig('BC_top_charcter_book_all.png')
plt.show()

# %%
#Closeness_Centrality
bet_cen_book_all = nx.closeness_centrality(books[5], distance='new_weight')
sorted_bet_cen_book_all = sorted(bet_cen_book_all.items(), key=lambda x:x[1], reverse=True)[0:10]
print('top10 of ALL Book: ','\n', sorted_bet_cen_book_all, '\n')
# Out:
# top10 of ALL Book:
#  [('Tyrion-Lannister', 0.4763331336129419), ('Robert-Baratheon', 0.4592720970537262), ('Eddard-Stark', 0.455848623853211), ('Cersei-Lannister', 0.45454545454545453), ('Jaime-Lannister', 0.4519613416714042), ('Jon-Snow', 0.44537815126050423), ('Stannis-Baratheon', 0.4446308724832215), ('Robb-Stark', 0.4441340782122905), ('Joffrey-Baratheon', 0.4339519650655022), ('Catelyn-Stark', 0.4334787350054526)]
